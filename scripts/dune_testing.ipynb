# %%
from dune_client.client import DuneClient
import pandas as pd
import logging
import os

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

try:
    from dotenv import load_dotenv
    if load_dotenv():
        logger.info("Loaded .env file")
    else:
        logger.info("No .env file found or loaded")
except ImportError:
    logger.info("dotenv not installed, skipping .env file loading")

DUNE_API_KEY = os.getenv('DUNE_API_KEY')
dune = DuneClient(DUNE_API_KEY)
query_result = dune.get_latest_result(4118421)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2024-10-22 19:18:10,761 INFO numexpr.utils NumExpr defaulting to 8 threads.
# 2024-10-22 19:18:11,325 INFO __main__ Loaded .env file

# %%
query_result_time = query_result.times.execution_ended_at
print(f"Query result time: {query_result_time}")
# Out:
# Query result time: 2024-10-02 02:16:40.898973+00:00

# %%
query_result_df = pd.DataFrame(query_result.result.rows)
query_result_df
# Out:
#                                          address blockchain            ens  \
# 0     0x8c180840fcbb90ce8464b4ecd12ab0f840c6647c   arbitrum
# 1     0x411f9a3cf8b761c0b29a7c18f0ca228c8e79beb3   arbitrum
# 2     0x8c180840fcbb90ce8464b4ecd12ab0f840c6647c   arbitrum
# 3     0xa5bf3bc76efa40bf86adcd6a934f38768a3faa2b   arbitrum
# 4     0xcd45e627e37b7f85266f4a9c6d3255f5f6448d6a   arbitrum
# ...                                          ...        ...            ...
# 1792  0x0dcfa173c7a786844a122d92f3d83e0d5b8e438a   arbitrum
# 1793  0x01ae8d6d0f137cf946e354ea707b698e8cae6485   arbitrum  maslineze.eth
# 1794  0x01ae8d6d0f137cf946e354ea707b698e8cae6485   arbitrum  maslineze.eth
# 1795  0x01ae8d6d0f137cf946e354ea707b698e8cae6485   arbitrum  maslineze.eth
# 1796  0x2cde9919e81b20b4b33dd562a48a84b54c48f00c   arbitrum
#
#       number_of_points            role  \
# 0           593.109281    contract_dev
# 1           637.937090         grantee
# 2           593.109281    contract_dev
# 3           593.109281  round_operator
# 4           548.281473         grantee
# ...                ...             ...
# 1792          0.000000         grantee
# 1793          5.871555         grantee
# 1794          5.857860         grantee
# 1795         16.192050         grantee
# 1796          0.000000         grantee
#
#                                           strategy_name  \
# 0     DonationVotingMerkleDistributionDirectTransfer...
# 1     DonationVotingMerkleDistributionDirectTransfer...
# 2     DonationVotingMerkleDistributionDirectTransfer...
# 3     DonationVotingMerkleDistributionDirectTransfer...
# 4     DonationVotingMerkleDistributionDirectTransfer...
# ...                                                 ...
# 1792                                               None
# 1793                                               None
# 1794                                               None
# 1795                                               None
# 1796                                               None
#
#                                                 tx_hash  \
# 0     0xe51225539ab9a6797ace9dc406d1c35a25b4b9f3a998...
# 1     0xe51225539ab9a6797ace9dc406d1c35a25b4b9f3a998...
# 2     0xe51225539ab9a6797ace9dc406d1c35a25b4b9f3a998...
# 3     0xe51225539ab9a6797ace9dc406d1c35a25b4b9f3a998...
# 4     0xe51225539ab9a6797ace9dc406d1c35a25b4b9f3a998...
# ...                                                 ...
# 1792  0x4e05f09c886a8a43a683b14acab78ba96b1dcd2d2cfe...
# 1793  0xd5d2b5be78e948d40013442ba6df4ab9bf08f95b93c1...
# 1794  0x2d28527707ec7c60365f9e26335093ddacd645d55441...
# 1795  0xfe1eceaae72fa6e41728c02588052c96f5f05b0c30e4...
# 1796  0x8f7864c8541ad6ff3c1af8bcae651c30364249331083...
#
#                      tx_timestamp
# 0     2024-09-23 12:58:53.000 UTC
# 1     2024-09-23 12:58:53.000 UTC
# 2     2024-09-23 12:58:53.000 UTC
# 3     2024-09-23 12:58:53.000 UTC
# 4     2024-09-23 12:58:53.000 UTC
# ...                           ...
# 1792  2024-03-29 00:02:54.000 UTC
# 1793  2024-03-10 16:22:58.000 UTC
# 1794  2024-03-10 16:12:50.000 UTC
# 1795  2024-02-27 17:36:59.000 UTC
# 1796  2024-01-11 04:12:14.000 UTC
#
# [1797 rows x 8 columns]

# %%
query_result_df.to_csv("allov2_distributions_oct22_2024.csv", index=False)
